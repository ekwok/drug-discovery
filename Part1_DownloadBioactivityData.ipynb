# %% [markdown]
# # Part 1 - Download Bioactivity Data
# Eric Kwok
#
# This notebook is based on [Computational Drug Discovery [Part 1] Download Bioactivity Data](https://github.com/dataprofessor/code/blob/master/python/CDD_ML_Part_1_bioactivity_data.ipynb) by Chanin Nantasenamat.
#
# ---
#
# ## ChEMBL Database
# The [ChEMBL Database](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents and 1.2 million assays. The data spans 13,000 targets and 1,800 cells and 33,000 indications. [Data as of May 18, 2020; ChEMBL version 27].
#
# ## Installing Libraries

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /Users/erickwok/opt/anaconda3/lib/python3.7/site-packages (0.10.2)
# Requirement already satisfied: requests-cache>=0.4.7 in /Users/erickwok/opt/anaconda3/lib/python3.7/site-packages (from chembl_webresource_client) (0.5.2)
# Requirement already satisfied: requests>=2.18.4 in /Users/erickwok/opt/anaconda3/lib/python3.7/site-packages (from chembl_webresource_client) (2.22.0)
# Requirement already satisfied: urllib3 in /Users/erickwok/opt/anaconda3/lib/python3.7/site-packages (from chembl_webresource_client) (1.25.8)
# Requirement already satisfied: easydict in /Users/erickwok/opt/anaconda3/lib/python3.7/site-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/erickwok/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.18.4->chembl_webresource_client) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/erickwok/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/erickwok/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.18.4->chembl_webresource_client) (2019.11.28)

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## Search for Target Protein
#
# ### Target Search for Influenza

# %%
target = new_client.target
target_query = target.search('influenza')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references  \
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4   [{'xref_id': 'P03438', 'xref_name': None, 'xre...
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8   [{'xref_id': 'P63231', 'xref_name': None, 'xre...
# 9                                                  []
# 10                                                 []
# 11                                                 []
#
#                                           organism  \
# 0                     unidentified influenza virus
# 1                                Influenza B virus
# 2                                Influenza A virus
# 3                                Influenza C virus
# 4           Influenza A virus (strain A/X-31 H3N2)
# 5                         Influenza A virus (H5N1)
# 6                           Influenza A virus H3N2
# 7            Unidentified Influenza A virus (H1N2)
# 8       Influenza A virus (A/Udorn/307/1972(H3N2))
# 9                     Influenza B virus (B/Lee/40)
# 10  Influenza A virus (A/Puerto Rico/8/1934(H1N1))
# 11                          Haemophilus influenzae
#
#                                 pref_name  score  species_group_flag  \
# 0            unidentified influenza virus   12.0               False
# 1                       Influenza B virus   12.0               False
# 2                       Influenza A virus   12.0               False
# 3                       Influenza C virus   12.0               False
# 4         Influenza A virus Hemagglutinin   10.0               False
# 5                Influenza A virus (H5N1)   10.0               False
# 6                  Influenza A virus H3N2   10.0               False
# 7   Unidentified Influenza A virus (H1N2)    9.0               False
# 8     Influenza virus A matrix protein M2    8.0               False
# 9            Influenza B virus (B/Lee/40)    8.0               False
# 10    Influenza A virus (A/PR/8/34(H1N1))    8.0               False
# 11                 Haemophilus influenzae    6.0               False
#
#    target_chembl_id                                  target_components  \
# 0      CHEMBL613128                                                 []
# 1      CHEMBL613129                                                 []
# 2      CHEMBL613740                                                 []
# 3      CHEMBL612783                                                 []
# 4        CHEMBL4918  [{'accession': 'P03438', 'component_descriptio...
# 5      CHEMBL613845                                                 []
# 6     CHEMBL2366902                                                 []
# 7     CHEMBL2367089                                                 []
# 8        CHEMBL2052  [{'accession': 'P0DOF8', 'component_descriptio...
# 9      CHEMBL612452                                                 []
# 10     CHEMBL612610                                                 []
# 11        CHEMBL355                                                 []
#
#        target_type   tax_id
# 0         ORGANISM    11309
# 1         ORGANISM    11520
# 2         ORGANISM    11320
# 3         ORGANISM    11552
# 4   SINGLE PROTEIN   132504
# 5         ORGANISM   102793
# 6         ORGANISM    41857
# 7         ORGANISM  1323429
# 8   SINGLE PROTEIN   381517
# 9         ORGANISM   107412
# 10        ORGANISM   211044
# 11        ORGANISM      727

# %% [markdown]
# ### Select and retrieve bioactivity data for Influenza A virus (third entry)

# %%
selected_target = targets.target_chembl_id[2]
selected_target
# Out:
# 'CHEMBL613740'

# %% [markdown]
# Here, we will retrieve only bioactivity data for Influenza A virus Hemagglutinin that are reported as IC50 values in nM (nanomolar) unit.

# %%
activity = new_client.activity
result = activity.filter(target_chembl_id=selected_target).filter(standard_type='IC50')
df = pd.DataFrame.from_dict(result)
df
# Out:
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                None        76866                  []    CHEMBL808323
# 1                None        76868                  []    CHEMBL808324
# 2                None        77906                  []    CHEMBL808323
# 3                None        77908                  []    CHEMBL808324
# 4                None        79067                  []    CHEMBL808323
# ...               ...          ...                 ...             ...
# 1692             None     18746013                  []   CHEMBL4262939
# 1693             None     18746014                  []   CHEMBL4262939
# 1694             None     18746015                  []   CHEMBL4262939
# 1695             None     18746016                  []   CHEMBL4262939
# 1696             None     18761310                  []   CHEMBL4266352
#
#                                       assay_description assay_type  \
# 0     The compound was tested in vitro for the inhib...          F
# 1     The compound was tested in vitro for the inhib...          F
# 2     The compound was tested in vitro for the inhib...          F
# 3     The compound was tested in vitro for the inhib...          F
# 4     The compound was tested in vitro for the inhib...          F
# ...                                                 ...        ...
# 1692  Antiviral activity against Influenza A virus (...          F
# 1693  Antiviral activity against Influenza A virus (...          F
# 1694  Antiviral activity against Influenza A virus (...          F
# 1695  Antiviral activity against Influenza A virus (...          F
# 1696  Antiviral activity against Influenza A virus (...          F
#
#      bao_endpoint   bao_format              bao_label  \
# 0     BAO_0000190  BAO_0000218  organism-based format
# 1     BAO_0000190  BAO_0000218  organism-based format
# 2     BAO_0000190  BAO_0000218  organism-based format
# 3     BAO_0000190  BAO_0000218  organism-based format
# 4     BAO_0000190  BAO_0000218  organism-based format
# ...           ...          ...                    ...
# 1692  BAO_0000190  BAO_0000218  organism-based format
# 1693  BAO_0000190  BAO_0000218  organism-based format
# 1694  BAO_0000190  BAO_0000218  organism-based format
# 1695  BAO_0000190  BAO_0000218  organism-based format
# 1696  BAO_0000190  BAO_0000218  organism-based format
#
#                                        canonical_smiles  ...  \
# 0                       CC(=O)Nc1ccc(C(=O)O)cc1NC(=O)CO  ...
# 1                       CC(=O)Nc1ccc(C(=O)O)cc1NC(=O)CO  ...
# 2                CC(=O)Nc1c(O)cc(C(=O)O)cc1[N+](=O)[O-]  ...
# 3                CC(=O)Nc1c(O)cc(C(=O)O)cc1[N+](=O)[O-]  ...
# 4          CC(=O)Nc1c(OC(C)=O)cc(C(=O)O)cc1[N+](=O)[O-]  ...
# ...                                                 ...  ...
# 1692  C=C(C)[C@@H]1CC[C@]2(C(=O)N[C@H]3C=C(C(=O)OC)O...  ...
# 1693  COC(=O)C1=C[C@H](NC(=O)[C@]23CCC(C)(C)C[C@H]2C...  ...
# 1694  C=C(C)[C@@H]1CC[C@]2(C(=O)N[C@H]3C=C(C(=O)OC)O...  ...
# 1695  COc1cc(/C=C/C(=O)CC(=O)/C=C/c2ccc(O)c(OC)c2)ccc1O  ...
# 1696  C=C[C@@H](O)Cc1nsc(C2=CCCS[C@]23C(=O)Nc2ccccc2...  ...
#
#         target_organism   target_pref_name target_tax_id text_value  toid  \
# 0     Influenza A virus  Influenza A virus         11320       None  None
# 1     Influenza A virus  Influenza A virus         11320       None  None
# 2     Influenza A virus  Influenza A virus         11320       None  None
# 3     Influenza A virus  Influenza A virus         11320       None  None
# 4     Influenza A virus  Influenza A virus         11320       None  None
# ...                 ...                ...           ...        ...   ...
# 1692  Influenza A virus  Influenza A virus         11320       None  None
# 1693  Influenza A virus  Influenza A virus         11320       None  None
# 1694  Influenza A virus  Influenza A virus         11320       None  None
# 1695  Influenza A virus  Influenza A virus         11320       None  None
# 1696  Influenza A virus  Influenza A virus         11320       None  None
#
#       type units    uo_units upper_value  value
# 0     IC50    mM  UO_0000065        None    4.0
# 1     IC50    mM  UO_0000065        None   10.0
# 2     IC50    mM  UO_0000065        None   0.75
# 3     IC50    mM  UO_0000065        None    1.0
# 4     IC50    mM  UO_0000065        None    5.0
# ...    ...   ...         ...         ...    ...
# 1692  IC50    uM  UO_0000065        None  100.0
# 1693  IC50    uM  UO_0000065        None   40.5
# 1694  IC50    uM  UO_0000065        None  100.0
# 1695  IC50    uM  UO_0000065        None    6.7
# 1696  IC50    uM  UO_0000065        None   33.3
#
# [1697 rows x 43 columns]

# %% [markdown]
# Finally, we will save the resulting bioactivity data to a CSV file **influenza_a_bioactivity.csv**.

# %%
df.to_csv('influenza_a_bioactivity.csv', index=False)

# %% [markdown]
# ## Handling Missing Data
# Drop compounds that are missing a value in the **standard_value** column.

# %%
df2 = df[df.standard_value.notnull()]
df2
# Out:
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                None        76866                  []    CHEMBL808323
# 1                None        76868                  []    CHEMBL808324
# 2                None        77906                  []    CHEMBL808323
# 3                None        77908                  []    CHEMBL808324
# 4                None        79067                  []    CHEMBL808323
# ...               ...          ...                 ...             ...
# 1692             None     18746013                  []   CHEMBL4262939
# 1693             None     18746014                  []   CHEMBL4262939
# 1694             None     18746015                  []   CHEMBL4262939
# 1695             None     18746016                  []   CHEMBL4262939
# 1696             None     18761310                  []   CHEMBL4266352
#
#                                       assay_description assay_type  \
# 0     The compound was tested in vitro for the inhib...          F
# 1     The compound was tested in vitro for the inhib...          F
# 2     The compound was tested in vitro for the inhib...          F
# 3     The compound was tested in vitro for the inhib...          F
# 4     The compound was tested in vitro for the inhib...          F
# ...                                                 ...        ...
# 1692  Antiviral activity against Influenza A virus (...          F
# 1693  Antiviral activity against Influenza A virus (...          F
# 1694  Antiviral activity against Influenza A virus (...          F
# 1695  Antiviral activity against Influenza A virus (...          F
# 1696  Antiviral activity against Influenza A virus (...          F
#
#      bao_endpoint   bao_format              bao_label  \
# 0     BAO_0000190  BAO_0000218  organism-based format
# 1     BAO_0000190  BAO_0000218  organism-based format
# 2     BAO_0000190  BAO_0000218  organism-based format
# 3     BAO_0000190  BAO_0000218  organism-based format
# 4     BAO_0000190  BAO_0000218  organism-based format
# ...           ...          ...                    ...
# 1692  BAO_0000190  BAO_0000218  organism-based format
# 1693  BAO_0000190  BAO_0000218  organism-based format
# 1694  BAO_0000190  BAO_0000218  organism-based format
# 1695  BAO_0000190  BAO_0000218  organism-based format
# 1696  BAO_0000190  BAO_0000218  organism-based format
#
#                                        canonical_smiles  ...  \
# 0                       CC(=O)Nc1ccc(C(=O)O)cc1NC(=O)CO  ...
# 1                       CC(=O)Nc1ccc(C(=O)O)cc1NC(=O)CO  ...
# 2                CC(=O)Nc1c(O)cc(C(=O)O)cc1[N+](=O)[O-]  ...
# 3                CC(=O)Nc1c(O)cc(C(=O)O)cc1[N+](=O)[O-]  ...
# 4          CC(=O)Nc1c(OC(C)=O)cc(C(=O)O)cc1[N+](=O)[O-]  ...
# ...                                                 ...  ...
# 1692  C=C(C)[C@@H]1CC[C@]2(C(=O)N[C@H]3C=C(C(=O)OC)O...  ...
# 1693  COC(=O)C1=C[C@H](NC(=O)[C@]23CCC(C)(C)C[C@H]2C...  ...
# 1694  C=C(C)[C@@H]1CC[C@]2(C(=O)N[C@H]3C=C(C(=O)OC)O...  ...
# 1695  COc1cc(/C=C/C(=O)CC(=O)/C=C/c2ccc(O)c(OC)c2)ccc1O  ...
# 1696  C=C[C@@H](O)Cc1nsc(C2=CCCS[C@]23C(=O)Nc2ccccc2...  ...
#
#         target_organism   target_pref_name target_tax_id text_value  toid  \
# 0     Influenza A virus  Influenza A virus         11320       None  None
# 1     Influenza A virus  Influenza A virus         11320       None  None
# 2     Influenza A virus  Influenza A virus         11320       None  None
# 3     Influenza A virus  Influenza A virus         11320       None  None
# 4     Influenza A virus  Influenza A virus         11320       None  None
# ...                 ...                ...           ...        ...   ...
# 1692  Influenza A virus  Influenza A virus         11320       None  None
# 1693  Influenza A virus  Influenza A virus         11320       None  None
# 1694  Influenza A virus  Influenza A virus         11320       None  None
# 1695  Influenza A virus  Influenza A virus         11320       None  None
# 1696  Influenza A virus  Influenza A virus         11320       None  None
#
#       type units    uo_units upper_value  value
# 0     IC50    mM  UO_0000065        None    4.0
# 1     IC50    mM  UO_0000065        None   10.0
# 2     IC50    mM  UO_0000065        None   0.75
# 3     IC50    mM  UO_0000065        None    1.0
# 4     IC50    mM  UO_0000065        None    5.0
# ...    ...   ...         ...         ...    ...
# 1692  IC50    uM  UO_0000065        None  100.0
# 1693  IC50    uM  UO_0000065        None   40.5
# 1694  IC50    uM  UO_0000065        None  100.0
# 1695  IC50    uM  UO_0000065        None    6.7
# 1696  IC50    uM  UO_0000065        None   33.3
#
# [1591 rows x 43 columns]

# %% [markdown]
# ## Data Pre-Processing
# ### Label compounds as being either active, inactive, or intermediate
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered **active** and those having values greater than 10,000 nM will be considered **inactive**. Compounds with values in between 1,000 and 10,000 nM will be considered **intermediate**.

# %%
bioactivity_class = []
for value in df2.standard_value.astype('float64'):
    if value <= 1000:
        bioactivity_class.append('active')
    elif value >= 10000:
        bioactivity_class.append('inactive')
    else:
        bioactivity_class.append('intermediate')
print(len(bioactivity_class))
# Out:
# 1591

# %% [markdown]
# ### Create new dataframe with metrics of interest
# In addition to the bioactivity class, we would like to analyze the following columns:
# - molecule_chembl_id
# - canonical_smiles
# - standard_value

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection].reset_index(drop=True)
df3.to_csv('df3_selection.csv')
df3 = pd.concat([df3, pd.DataFrame(bioactivity_class, columns=['bioactivity_class'])], axis=1)
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL327097                    CC(=O)Nc1ccc(C(=O)O)cc1NC(=O)CO
# 1          CHEMBL327097                    CC(=O)Nc1ccc(C(=O)O)cc1NC(=O)CO
# 2          CHEMBL324455             CC(=O)Nc1c(O)cc(C(=O)O)cc1[N+](=O)[O-]
# 3          CHEMBL324455             CC(=O)Nc1c(O)cc(C(=O)O)cc1[N+](=O)[O-]
# 4          CHEMBL321393       CC(=O)Nc1c(OC(C)=O)cc(C(=O)O)cc1[N+](=O)[O-]
# ...                 ...                                                ...
# 1586      CHEMBL4286184  C=C(C)[C@@H]1CC[C@]2(C(=O)N[C@H]3C=C(C(=O)OC)O...
# 1587      CHEMBL4294084  COC(=O)C1=C[C@H](NC(=O)[C@]23CCC(C)(C)C[C@H]2C...
# 1588      CHEMBL4282791  C=C(C)[C@@H]1CC[C@]2(C(=O)N[C@H]3C=C(C(=O)OC)O...
# 1589          CHEMBL140  COc1cc(/C=C/C(=O)CC(=O)/C=C/c2ccc(O)c(OC)c2)ccc1O
# 1590      CHEMBL4286137  C=C[C@@H](O)Cc1nsc(C2=CCCS[C@]23C(=O)Nc2ccccc2...
#
#      standard_value bioactivity_class
# 0         4000000.0          inactive
# 1        10000000.0          inactive
# 2          750000.0          inactive
# 3         1000000.0          inactive
# 4         5000000.0          inactive
# ...             ...               ...
# 1586       100000.0          inactive
# 1587        40500.0          inactive
# 1588       100000.0          inactive
# 1589         6700.0      intermediate
# 1590        33300.0          inactive
#
# [1591 rows x 4 columns]

# %% [markdown]
# Write to CSV file.

# %%
df3.to_csv('influenza_a_preprocessed.csv', index=False)
